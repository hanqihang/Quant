# %%
print("hello world!")
# Out:
# hello world!

# %%
x = 6
y = "hello world   "
print(y[3])
print(y[2:4])
print(y[::-1])
print(y.strip())
y.find("e") #if finded, print the index; if not, print -1

for i in range(10):
    x += 1
# Out:
# l
# ll
#    dlrow olleh
# hello world

# %%
print(x + 1)
# Out:
# 17

# %%
list1 = [2, 3, 5]
list1.append(1)
list1
list2 = [4, 5, 6]
list = list1 + list2
list
# Out:
# [2, 3, 5, 1, 4, 5, 6]
